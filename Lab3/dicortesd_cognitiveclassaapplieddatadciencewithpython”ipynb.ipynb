# %% [markdown]
# ![Captura de pantalla 2022-09-27 093630.png](data:image/png;base64,...)![Captura de pantalla 2022-09-27 093715.png](data:image/png;base64,...)![Captura de pantalla 2022-09-27 093758.png](data:image/png;base64,...)![Captura de pantalla 2022-09-27 094004.png](data:image/png;base64,...)
